# %%
import sqlalchemy
engine = sqlalchemy.create_engine('postgresql://postgres:admin@localhost:5432/music')
engine
connection = engine.connect()

connection.execute("""INSERT INTO singers(singer_name)
            VALUES('Hurts');
 """)
connection.execute("""INSERT INTO singers(singer_name)
            VALUES('My Chemical Romance');
 """)
connection.execute("""INSERT INTO singers(singer_name)
            VALUES('Caliban');
 """)
connection.execute("""INSERT INTO singers(singer_name)
            VALUES('Green Day');
 """)
connection.execute("""INSERT INTO singers(singer_name)
            VALUES('Lynyrd Skynyrd');
 """)
connection.execute("""INSERT INTO singers(singer_name)
            VALUES('Willie Nelson');
 """)
connection.execute("""INSERT INTO singers(singer_name)
            VALUES('Kaleo');
 """)
connection.execute("""INSERT INTO singers(singer_name)
            VALUES('Nirvana');
 """)
connection.execute("""INSERT INTO singers(singer_name)
            VALUES('Nomy');
 """)

connection.execute("""INSERT INTO genre(title)
             VALUES('Сountry');
  """)
connection.execute("""INSERT INTO genre(title)
             VALUES('Indie Rock');
  """)
connection.execute("""INSERT INTO genre(title)
             VALUES('Metalcore');
  """)
connection.execute("""INSERT INTO genre(title)
             VALUES('Blues Rock');
  """)
connection.execute("""INSERT INTO genre(title)
             VALUES('Punk Rock');
  """)
connection.execute("""INSERT INTO genre(title)
             VALUES('Alternative Rock');
  """)

connection.execute("""INSERT INTO singersgenre
             VALUES(1,2);
  """)
connection.execute("""INSERT INTO singersgenre
             VALUES(2,5);
  """)
connection.execute("""INSERT INTO singersgenre
             VALUES(2,6);
  """)
connection.execute("""INSERT INTO singersgenre
             VALUES(3,3);
  """)
connection.execute("""INSERT INTO singersgenre
             VALUES(4,2);
  """)
connection.execute("""INSERT INTO singersgenre
             VALUES(4,6);
  """)
connection.execute("""INSERT INTO singersgenre
             VALUES(5,4);
  """)
connection.execute("""INSERT INTO singersgenre
             VALUES(6,1);
  """)
connection.execute("""INSERT INTO singersgenre
             VALUES(7,2);
  """)
connection.execute("""INSERT INTO singersgenre
             VALUES(7,6);
  """)
connection.execute("""INSERT INTO singersgenre
             VALUES(8,6);
  """)
connection.execute("""INSERT INTO singersgenre
             VALUES(8,5);
  """)
connection.execute("""INSERT INTO singersgenre
             VALUES(9,6);
  """)
connection.execute("""INSERT INTO singersgenre
             VALUES(9,1);
  """)

connection.execute("""INSERT INTO albums(album_title, album_date)
              VALUES('Happiness', 2020);
   """)
connection.execute("""INSERT INTO albums(album_title, album_date)
              VALUES('Danger Days', 2010);
   """)
connection.execute("""INSERT INTO albums(album_title, album_date)
              VALUES('The Undying Darkness', 2006);
   """)
connection.execute("""INSERT INTO albums(album_title, album_date)
              VALUES('American Idiot', 2004);
   """)
connection.execute("""INSERT INTO albums(album_title, album_date)
              VALUES('Live in Atlantic City', 2018);
   """)
connection.execute("""INSERT INTO albums(album_title, album_date)
              VALUES('Good Times', 1968);
   """)
connection.execute("""INSERT INTO albums(album_title, album_date)
              VALUES('A/B', 2016);
   """)
connection.execute("""INSERT INTO albums(album_title, album_date)
              VALUES('Nevermind', 1991);
   """)
connection.execute("""INSERT INTO albums(album_title, album_date)
              VALUES('The end of the world', 2018);
   """)

connection.execute("""INSERT INTO albumssinger
              VALUES(1,1);
   """)
connection.execute("""INSERT INTO albumssinger
              VALUES(2,2);
   """)
connection.execute("""INSERT INTO albumssinger
              VALUES(3,3);
   """)
connection.execute("""INSERT INTO albumssinger
              VALUES(4,4);
   """)
connection.execute("""INSERT INTO albumssinger
              VALUES(5,5);
   """)
connection.execute("""INSERT INTO albumssinger
              VALUES(6,6);
   """)
connection.execute("""INSERT INTO albumssinger
              VALUES(7,7);
   """)
connection.execute("""INSERT INTO albumssinger
              VALUES(8,8);
   """)
connection.execute("""INSERT INTO albumssinger
              VALUES(9,9);
   """)

connection.execute("""INSERT INTO songs(title, song_time, album_id)
              VALUES('Illuminated', 03.19, 1);
   """)
connection.execute("""INSERT INTO songs(title, song_time, album_id)
              VALUES('Unspoken', 04.45, 1);
   """)
connection.execute("""INSERT INTO songs(title, song_time, album_id)
              VALUES('Destroya', 04.33, 2);
   """)
connection.execute("""INSERT INTO songs(title, song_time, album_id)
              VALUES('Party Poison', 03.36, 2);
   """)
connection.execute("""INSERT INTO songs(title, song_time, album_id)
              VALUES('My Fiction Beauty', 04.40, 3);
   """)
connection.execute("""INSERT INTO songs(title, song_time, album_id)
              VALUES('I Rape Myself', 03.24, 3);
   """)
connection.execute("""INSERT INTO songs(title, song_time, album_id)
              VALUES('Jesus of Suborbia', 09.08, 4);
   """)
connection.execute("""INSERT INTO songs(title, song_time, album_id)
              VALUES('American Idiot', 02.54, 4);
   """)
connection.execute("""INSERT INTO songs(title, song_time, album_id)
              VALUES('Sweet Home Alabama', 06.52, 5);
   """)
connection.execute("""INSERT INTO songs(title, song_time, album_id)
              VALUES('Gimme Back My Bullets', 03.17, 5);
   """)
connection.execute("""INSERT INTO songs(title, song_time, album_id)
              VALUES('Sweet Memories', 03.12, 6);
   """)
connection.execute("""INSERT INTO songs(title, song_time, album_id)
              VALUES('Pages', 02.49, 6);
   """)
connection.execute("""INSERT INTO songs(title, song_time, album_id)
              VALUES('Broken Bones', 04.06, 7);
   """)
connection.execute("""INSERT INTO songs(title, song_time, album_id)
              VALUES('No Good', 03.54, 7);
   """)
connection.execute("""INSERT INTO songs(title, song_time, album_id)
              VALUES('In Bloom', 04.15, 8);
   """)
connection.execute("""INSERT INTO songs(title, song_time, album_id)
              VALUES('Polly', 02.57, 8);
   """)
connection.execute("""INSERT INTO songs(title, song_time, album_id)
              VALUES('Society falls', 02.46, 9);
   """)
connection.execute("""INSERT INTO songs(title, song_time, album_id)
              VALUES('Get a name', 03.31, 9);
   """)

connection.execute("""INSERT INTO collection(collection_name, collection_date)
              VALUES('Back to young', 2021);
   """)
connection.execute("""INSERT INTO collection(collection_name, collection_date)
              VALUES('For chill', 2014);
   """)
connection.execute("""INSERT INTO collection(collection_name, collection_date)
              VALUES('To the car', 2019);
   """)
connection.execute("""INSERT INTO collection(collection_name, collection_date)
              VALUES('For sport', 2018);
   """)
connection.execute("""INSERT INTO collection(collection_name, collection_date)
              VALUES('Not listened to', 2020);
   """)
connection.execute("""INSERT INTO collection(collection_name, collection_date)
              VALUES('From Father', 2017);
   """)
connection.execute("""INSERT INTO collection(collection_name, collection_date)
              VALUES('For walking', 2015);
   """)
connection.execute("""INSERT INTO collection(collection_name, collection_date)
              VALUES('Favorites', 2022);
   """)

connection.execute("""INSERT INTO collectionsongs
              VALUES(15,1);
   """)
connection.execute("""INSERT INTO collectionsongs
              VALUES(9,1);
   """)
connection.execute("""INSERT INTO collectionsongs
              VALUES(16,1);
   """)
connection.execute("""INSERT INTO collectionsongs
              VALUES(2,2);
   """)
connection.execute("""INSERT INTO collectionsongs
              VALUES(13,2);
   """)
connection.execute("""INSERT INTO collectionsongs
              VALUES(15,2);
   """)
connection.execute("""INSERT INTO collectionsongs
              VALUES(1,3);
   """)
connection.execute("""INSERT INTO collectionsongs
              VALUES(6,3);
   """)
connection.execute("""INSERT INTO collectionsongs
              VALUES(12,4);
   """)
connection.execute("""INSERT INTO collectionsongs
              VALUES(16,4);
   """)
connection.execute("""INSERT INTO collectionsongs
              VALUES(5,5);
   """)
connection.execute("""INSERT INTO collectionsongs
              VALUES(8,5);
   """)
connection.execute("""INSERT INTO collectionsongs
              VALUES(3,6);
   """)
connection.execute("""INSERT INTO collectionsongs
              VALUES(4,6);
   """)
connection.execute("""INSERT INTO collectionsongs
              VALUES(18,7);
   """)
connection.execute("""INSERT INTO collectionsongs
              VALUES(7,7);
   """)
connection.execute("""INSERT INTO collectionsongs
              VALUES(17,8);
   """)
connection.execute("""INSERT INTO collectionsongs
              VALUES(10,8);
   """)
connection.execute("""INSERT INTO collectionsongs
              VALUES(4,8);
   """)

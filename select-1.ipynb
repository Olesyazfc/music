# %%
import sqlalchemy
engine = sqlalchemy.create_engine('postgresql://postgres:123890zcrjhgbjy@localhost:5432/music')
engine
connection = engine.connect()

print(connection.execute(
"""
SELECT DISTINCT title, COUNT(singer_name) FROM genre g 
JOIN singersgenre sg ON g.id = sg.genre_id
JOIN singers s ON sg.singer_id = s.id
GROUP BY title;
""").fetchall())

print(connection.execute(
"""
SELECT COUNT(title) FROM songs s 
JOIN albums a ON s.album_id = a.id
WHERE album_date BETWEEN 2015 AND 2020;
""").fetchall())

print(connection.execute(
"""
SELECT album_title, ROUND(AVG(song_time), 3) FROM songs s 
JOIN albums a ON s.album_id = a.id
GROUP BY album_title;
""").fetchall())

print(connection.execute(
"""
SELECT singer_name, album_date FROM singers s
JOIN albumssinger ams ON s.id = ams.singer_id
JOIN albums a ON ams.album_id = a.id
WHERE(
SELECT album_date FROM singers limit 1) NOT IN (2020);
""").fetchall())

print(connection.execute(
"""
SELECT collection_name FROM collection c
JOIN collectionsongs cs ON c.id = cs.collection_id
JOIN songs s ON cs.song_id = s.id
JOIN albums a ON s.album_id = a.id
JOIN albumssinger ams ON a.id = ams.album_id
JOIN singers si ON ams.singer_id = si.id
WHERE singer_name IN ('Nomy');
""").fetchall())

print(connection.execute(
"""
SELECT album_title FROM albums a
JOIN albumssinger ams ON a.id = ams.album_id
JOIN singers s ON ams.singer_id = s.id
JOIN singersgenre sg ON s.id = sg.singer_id
GROUP BY album_title, singer_name
HAVING COUNT(genre_id) > 1;
""").fetchall())

print(connection.execute(
"""
SELECT title FROM songs s
JOIN collectionsongs cs ON s.id = cs.song_id
JOIN collection c ON cs.collection_id = c.id
WHERE c.id IS NULL;
""").fetchall())

print(connection.execute(
"""
SELECT singer_name FROM singers s
JOIN albumssinger ams ON s.id = ams.singer_id
JOIN albums a ON ams.album_id = a.id
JOIN songs so ON a.id = so.album_id
WHERE song_time = (
SELECT MIN(song_time) from songs);
""").fetchall())


print(connection.execute(
"""
SELECT album_title from albums a
JOIN songs s ON a.id = s.album_id
GROUP BY album_title
HAVING COUNT(album_title) = (
SELECT MIN(count_title) FROM
(SELECT COUNT(title) count_title FROM albums a
JOIN songs s ON a.id = s.album_id
GROUP BY album_title) X)
;
""").fetchall())
# Out:
# [('Indie Rock', 3), ('Punk Rock', 2), ('Blues Rock', 1), ('Metalcore', 1), ('Сountry', 2), ('Alternative Rock', 5)]
# [(8,)]
# [('A/B', Decimal('3.800')), ('Nevermind', Decimal('3.360')), ('The Undying Darkness', Decimal('3.820')), ('Danger Days', Decimal('3.845')), ('Good Times', Decimal('2.805')), ('Happiness', Decimal('3.820')), ('Live in Atlantic City', Decimal('4.845')), ('The end of the world', Decimal('2.885')), ('American Idiot', Decimal('5.810'))]
# [('My Chemical Romance', 2010), ('Caliban', 2006), ('Green Day', 2004), ('Lynyrd Skynyrd', 2018), ('Willie Nelson', 1968), ('Kaleo', 2016), ('Nirvana', 1991), ('Nomy', 2018)]
# [('For walking',), ('From Father',)]
# [('The end of the world',), ('Danger Days',), ('American Idiot',), ('A/B',), ('Nevermind',)]
# []
# [('Nomy',)]
# [('A/B',), ('Nevermind',), ('The Undying Darkness',), ('Danger Days',), ('Good Times',), ('Happiness',), ('Live in Atlantic City',), ('The end of the world',), ('American Idiot',)]
